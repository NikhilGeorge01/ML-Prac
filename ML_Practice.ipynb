# %% [markdown]
# <a href="https://colab.research.google.com/github/NikhilGeorge01/ML-Prac/blob/main/ML_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    2014: [100.5, 150.8, 200.9, 30000, 40000],
    2015: [12000, 18000, 22000, 30000, 45000],
    2016: [20000, 50000, 70000, 100000, 125000],
    2017: [50000, 60000, 70000, 80000, 90000]
}

sales_persons = ['Madhu', 'Kusum', 'Kinshuk', 'Ankit', 'Shruti']

Sales = pd.DataFrame(data, index=sales_persons)
print(Sales)
# Out:
#             2014   2015    2016   2017
# Madhu      100.5  12000   20000  50000
# Kusum      150.8  18000   50000  60000
# Kinshuk    200.9  22000   70000  70000
# Ankit    30000.0  30000  100000  80000
# Shruti   40000.0  45000  125000  90000

# %%
print(Sales.index)
# Out:
# Index(['Madhu', 'Kusum', 'Kinshuk', 'Ankit', 'Shruti'], dtype='object')

# %%
print(Sales.columns)
# Out:
# Index([2014, 2015, 2016, 2017], dtype='int64')

# %%
print(Sales.dtypes)
# Out:
# 2014    float64
# 2015      int64
# 2016      int64
# 2017      int64
# dtype: object

# %%
print("Dimensions:", Sales.ndim)
print("Shape:", Sales.shape)
print("Size:", Sales.size)
print("Values:\n", Sales.values)
# Out:
# Dimensions: 2
# Shape: (5, 4)
# Size: 20
# Values:
#  [[1.005e+02 1.200e+04 2.000e+04 5.000e+04]
#  [1.508e+02 1.800e+04 5.000e+04 6.000e+04]
#  [2.009e+02 2.200e+04 7.000e+04 7.000e+04]
#  [3.000e+04 3.000e+04 1.000e+05 8.000e+04]
#  [4.000e+04 4.500e+04 1.250e+05 9.000e+04]]

# %%
print(Sales.tail(2))
# Out:
#            2014   2015    2016   2017
# Ankit   30000.0  30000  100000  80000
# Shruti  40000.0  45000  125000  90000

# %%
print(Sales.iloc[:, :2])
# Out:
#             2014   2015
# Madhu      100.5  12000
# Kusum      150.8  18000
# Kinshuk    200.9  22000
# Ankit    30000.0  30000
# Shruti   40000.0  45000

# %%
data_2018 = {
    'Madhu': 160000,
    'Kusum': 110000,
    'Kinshuk': 500000,
    'Ankit': 340000,
    'Shruti': 900000
}
Sales2 = pd.DataFrame({2018: data_2018})
print(Sales2)
# Out:
#            2018
# Madhu    160000
# Kusum    110000
# Kinshuk  500000
# Ankit    340000
# Shruti   900000

# %% [markdown]
# SCIKIT LEARN

# %%
import sklearn

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
print(iris.data.shape)
# Out:
# (150, 4)

# %%
print(iris.data[:4])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]]

# %% [markdown]
# x_train indicates training data
#
# y_train indicates labels
#
# X_test indicates test data
#
# Y_test indicates labels of test data

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
X = iris.data
y = iris.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
print(y_test)
# Out:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0]

# %%
print(y_pred)
# Out:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0]

# %%
print(y_train)
# Out:
# [1 2 2 1 2 1 2 1 0 2 1 0 0 0 1 2 0 0 0 1 0 1 2 0 1 2 0 2 2 1 1 2 1 0 1 2 0
#  0 1 1 0 2 0 0 1 1 2 1 2 2 1 0 0 2 2 0 0 0 1 2 0 2 2 0 1 1 2 1 2 0 2 1 2 1
#  1 1 0 1 1 0 1 2 2 0 1 2 2 0 2 0 1 2 2 1 2 1 1 2 2 0 1 2 0 1 2]

# %%
import pandas as ppd

# %%
irisData = pd.read_csv('Iris.csv')

# %%
irisData.shape
# Out:
# (150, 6)

# %%
irisData.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
irisData.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
print(irisData.keys())
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
print(irisData.shape[0])
# Out:
# 150

# %%
print(irisData.shape[1])
# Out:
# 6

# %%
print(irisData.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# sklearn.model_selection.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)

# %%
print(irisData.isna())
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
irisData.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
setosa = irisData[irisData['Species'] == 'Iris-setosa']
versicolor = irisData[irisData['Species'] == 'Iris-versicolor']
virginica = irisData[irisData['Species'] == 'Iris-virginica']

# %%
print(setosa.head(3) )
print(versicolor.head(3))
print(virginica.head(3))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
#
#             Species
# 50  Iris-versicolor
# 51  Iris-versicolor
# 52  Iris-versicolor
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
#
#             Species
# ...

# %%
noId_Iris = irisData.drop('Id', axis=1)

# %%
print(noId_Iris.head())
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(irisData[:4])
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
print(irisData.loc[0:4])
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
irisData.set_index('Id', inplace=True)

# %%
print(irisData.loc[2:5])
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
value_counts = irisData['Species'].value_counts()
print(value_counts.values())
# Out:
# Index(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype='object', name='Species')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-111-2534696173.py in <cell line: 0>()
#       2
#       3 print(value_counts.keys())
# ----> 4 print(value_counts.values())
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(value_counts.index, value_counts.values)
plt.xlabel('Species')
plt.ylabel('Count')
plt.title('Distribution of Species')
plt.show()

# %%
plt.pie(value_counts.values, labels=value_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Species')
plt.show()

# %%
irisData.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
irisData.plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
import seaborn as sns
sns.pairplot(irisData , hue='Species')

# %%
sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=irisData, kind='scatter', color='blue')

# %%
sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=irisData, kind='hex', color='blue')

# %%
sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=irisData, kind='kde', color='blue')

# %%
sns.scatterplot(x=irisData.SepalLengthCm, y=irisData.SepalWidthCm, color='blue')

sns.kdeplot(x=irisData.SepalLengthCm, y=irisData.SepalWidthCm, color='blue', shade=True)

plt.show()
# Out:
# /tmp/ipython-input-136-4074499979.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=irisData.SepalLengthCm, y=irisData.SepalWidthCm, color='blue', shade=True)
